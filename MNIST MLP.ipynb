# %%
'''
Basic example originally from https://github.com/keras-team/keras/blob/master/examples/mnist_mlp.py

Trains a simple deep NN on the MNIST dataset.

Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''
# Out:
# '\nBasic example originally from https://github.com/keras-team/keras/blob/master/examples/mnist_mlp.py\n\nTrains a simple deep NN on the MNIST dataset.\n\nGets to 98.40% test accuracy after 20 epochs\n(there is *a lot* of margin for parameter tuning).\n2 seconds per epoch on a K520 GPU.\n'

# %% [markdown]
# # FeedForward Network

# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout 
from keras.optimizers import RMSprop
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare Data

# %%
batch_size = 128
num_classes = 10
epochs = 40

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
def test_model(model):
    model.summary()

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(x_test, y_test))


    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
    return history

# %% [markdown]
# ## No Hidden Layers

# %%
no_hidden_model = Sequential()
no_hidden_model.add(Dense(num_classes, activation='softmax', input_shape=(784,)))

no_hidden_history = test_model(no_hidden_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.5993 - acc: 0.8515 - val_loss: 0.3414 - val_acc: 0.9080
# Epoch 2/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.3308 - acc: 0.9082 - val_loss: 0.3010 - val_acc: 0.9165
# Epoch 3/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.3017 - acc: 0.9155 - val_loss: 0.2859 - val_acc: 0.9208
# Epoch 4/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2883 - acc: 0.9196 - val_loss: 0.2802 - val_acc: 0.9218
# Epoch 5/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2802 - acc: 0.9218 - val_loss: 0.2759 - val_acc: 0.9236
# Epoch 6/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2749 - acc: 0.9236 - val_loss: 0.2722 - val_acc: 0.9255
# Epoch 7/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2704 - acc: 0.9251 - val_loss: 0.2718 - val_acc: 0.9254
# Epoch 8/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2673 - acc: 0.9260 - val_loss: 0.2687 - val_acc: 0.9257
# Epoch 9/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2648 - acc: 0.9271 - val_loss: 0.2715 - val_acc: 0.9260
# Epoch 10/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2626 - acc: 0.9276 - val_loss: 0.2684 - val_acc: 0.9262
# Epoch 11/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2611 - acc: 0.9285 - val_loss: 0.2686 - val_acc: 0.9271
# Epoch 12/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2593 - acc: 0.9291 - val_loss: 0.2682 - val_acc: 0.9271
# Epoch 13/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2582 - acc: 0.9294 - val_loss: 0.2678 - val_acc: 0.9266
# Epoch 14/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2567 - acc: 0.9301 - val_loss: 0.2693 - val_acc: 0.9250
# Epoch 15/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2557 - acc: 0.9307 - val_loss: 0.2689 - val_acc: 0.9271
# Epoch 16/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2548 - acc: 0.9306 - val_loss: 0.2679 - val_acc: 0.9274
# Epoch 17/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2540 - acc: 0.9312 - val_loss: 0.2691 - val_acc: 0.9272
# Epoch 18/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2531 - acc: 0.9316 - val_loss: 0.2718 - val_acc: 0.9265
# Epoch 19/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2525 - acc: 0.9322 - val_loss: 0.2689 - val_acc: 0.9280
# Epoch 20/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2518 - acc: 0.9319 - val_loss: 0.2677 - val_acc: 0.9294
# Epoch 21/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2515 - acc: 0.9322 - val_loss: 0.2681 - val_acc: 0.9281
# Epoch 22/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2508 - acc: 0.9321 - val_loss: 0.2721 - val_acc: 0.9279
# Epoch 23/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2502 - acc: 0.9327 - val_loss: 0.2736 - val_acc: 0.9261
# Epoch 24/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2497 - acc: 0.9327 - val_loss: 0.2718 - val_acc: 0.9275
# Epoch 25/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2492 - acc: 0.9336 - val_loss: 0.2710 - val_acc: 0.9276
# Epoch 26/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2490 - acc: 0.9332 - val_loss: 0.2726 - val_acc: 0.9277
# Epoch 27/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2485 - acc: 0.9337 - val_loss: 0.2740 - val_acc: 0.9284
# Epoch 28/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2483 - acc: 0.9335 - val_loss: 0.2732 - val_acc: 0.9277
# Epoch 29/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2482 - acc: 0.9340 - val_loss: 0.2717 - val_acc: 0.9279
# Epoch 30/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2474 - acc: 0.9342 - val_loss: 0.2740 - val_acc: 0.9267
# Epoch 31/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2472 - acc: 0.9342 - val_loss: 0.2732 - val_acc: 0.9280
# Epoch 32/40
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.2470 - acc: 0.9343 - val_loss: 0.2739 - val_acc: 0.9287
# Epoch 33/40
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.2469 - acc: 0.9342 - val_loss: 0.2736 - val_acc: 0.9289
# Epoch 34/40
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.2464 - acc: 0.9347 - val_loss: 0.2775 - val_acc: 0.9271
# Epoch 35/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2463 - acc: 0.9346 - val_loss: 0.2765 - val_acc: 0.9279
# Epoch 36/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2460 - acc: 0.9347 - val_loss: 0.2764 - val_acc: 0.9274
# Epoch 37/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2457 - acc: 0.9349 - val_loss: 0.2762 - val_acc: 0.9275
# Epoch 38/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2457 - acc: 0.9353 - val_loss: 0.2756 - val_acc: 0.9287
# Epoch 39/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2454 - acc: 0.9350 - val_loss: 0.2765 - val_acc: 0.9281
# Epoch 40/40
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.2453 - acc: 0.9354 - val_loss: 0.2777 - val_acc: 0.9278
# Test loss: 0.27774093541800976
# Test accuracy: 0.9278

# %% [markdown]
# # One Hidden Layer

# %%
one_hidden_model = Sequential()
one_hidden_model.add(Dense(800, activation='relu', input_shape=(784,)))
one_hidden_model.add(Dropout(0.2))
one_hidden_model.add(Dense(num_classes, activation='softmax'))

one_hidden_history = test_model(one_hidden_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 800)               628000
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 800)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                8010
# =================================================================
# Total params: 636,010
# Trainable params: 636,010
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.2548 - acc: 0.9244 - val_loss: 0.1187 - val_acc: 0.9640
# Epoch 2/40
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.1048 - acc: 0.9681 - val_loss: 0.0854 - val_acc: 0.9734
# Epoch 3/40
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0728 - acc: 0.9778 - val_loss: 0.0768 - val_acc: 0.9761
# Epoch 4/40
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0541 - acc: 0.9835 - val_loss: 0.0732 - val_acc: 0.9786
# Epoch 5/40
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.0445 - acc: 0.9865 - val_loss: 0.0653 - val_acc: 0.9813
# Epoch 6/40
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0352 - acc: 0.9891 - val_loss: 0.0651 - val_acc: 0.9810
# Epoch 7/40
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0298 - acc: 0.9907 - val_loss: 0.0637 - val_acc: 0.9811
# Epoch 8/40
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0249 - acc: 0.9922 - val_loss: 0.0673 - val_acc: 0.9820
# Epoch 9/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0212 - acc: 0.9935 - val_loss: 0.0664 - val_acc: 0.9822
# Epoch 10/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0189 - acc: 0.9944 - val_loss: 0.0717 - val_acc: 0.9822
# Epoch 11/40
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.0167 - acc: 0.9945 - val_loss: 0.0701 - val_acc: 0.9833
# Epoch 12/40
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0136 - acc: 0.9956 - val_loss: 0.0683 - val_acc: 0.9847
# Epoch 13/40
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0125 - acc: 0.9962 - val_loss: 0.0693 - val_acc: 0.9832
# Epoch 14/40
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0116 - acc: 0.9962 - val_loss: 0.0781 - val_acc: 0.9819
# Epoch 15/40
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0893 - val_acc: 0.9808
# Epoch 16/40
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.0090 - acc: 0.9972 - val_loss: 0.0781 - val_acc: 0.9820
# Epoch 17/40
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0080 - acc: 0.9975 - val_loss: 0.0801 - val_acc: 0.9827
# Epoch 18/40
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0071 - acc: 0.9977 - val_loss: 0.0816 - val_acc: 0.9832
# Epoch 19/40
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0066 - acc: 0.9979 - val_loss: 0.0819 - val_acc: 0.9836
# Epoch 20/40
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0064 - acc: 0.9981 - val_loss: 0.0813 - val_acc: 0.9845
# Epoch 21/40
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0056 - acc: 0.9983 - val_loss: 0.0872 - val_acc: 0.9826
# Epoch 22/40
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0053 - acc: 0.9985 - val_loss: 0.0880 - val_acc: 0.9833
# Epoch 23/40
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0051 - acc: 0.9985 - val_loss: 0.0914 - val_acc: 0.9830
# Epoch 24/40
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.0053 - acc: 0.9985 - val_loss: 0.0882 - val_acc: 0.9822
# Epoch 25/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0045 - acc: 0.9986 - val_loss: 0.0837 - val_acc: 0.9847
# Epoch 26/40
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.0044 - acc: 0.9987 - val_loss: 0.0865 - val_acc: 0.9843
# Epoch 27/40
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0038 - acc: 0.9989 - val_loss: 0.0893 - val_acc: 0.9830
# Epoch 28/40
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0033 - acc: 0.9990 - val_loss: 0.0941 - val_acc: 0.9821
# Epoch 29/40
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0035 - acc: 0.9989 - val_loss: 0.0918 - val_acc: 0.9845
# Epoch 30/40
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0034 - acc: 0.9990 - val_loss: 0.0910 - val_acc: 0.9839
# Epoch 31/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0033 - acc: 0.9990 - val_loss: 0.1005 - val_acc: 0.9826
# Epoch 32/40
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0035 - acc: 0.9990 - val_loss: 0.0960 - val_acc: 0.9830
# Epoch 33/40
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.0030 - acc: 0.9992 - val_loss: 0.0970 - val_acc: 0.9834
# Epoch 34/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0031 - acc: 0.9991 - val_loss: 0.0977 - val_acc: 0.9832
# Epoch 35/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0032 - acc: 0.9991 - val_loss: 0.0991 - val_acc: 0.9835
# Epoch 36/40
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0022 - acc: 0.9995 - val_loss: 0.1022 - val_acc: 0.9829
# Epoch 37/40
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0027 - acc: 0.9993 - val_loss: 0.1017 - val_acc: 0.9840
# Epoch 38/40
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0026 - acc: 0.9992 - val_loss: 0.1164 - val_acc: 0.9826
# Epoch 39/40
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.0024 - acc: 0.9993 - val_loss: 0.1108 - val_acc: 0.9827
# Epoch 40/40
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0025 - acc: 0.9993 - val_loss: 0.1055 - val_acc: 0.9837
# Test loss: 0.10545002310989357
# Test accuracy: 0.9837

# %% [markdown]
# # Two Hidden Layers

# %%
two_hidden_model = Sequential()
two_hidden_model.add(Dense(800, activation='relu', input_shape=(784,)))
two_hidden_model.add(Dropout(0.2))
two_hidden_model.add(Dense(400, activation='relu'))
two_hidden_model.add(Dropout(0.2))
two_hidden_model.add(Dense(num_classes, activation='softmax'))

two_hidden_history = test_model(two_hidden_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 800)               628000
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 800)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 400)               320400
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                4010
# =================================================================
# Total params: 952,410
# Trainable params: 952,410
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.2412 - acc: 0.9255 - val_loss: 0.1055 - val_acc: 0.9676
# Epoch 2/40
# 60000/60000 [==============================] - 8s 135us/step - loss: 0.0974 - acc: 0.9707 - val_loss: 0.0959 - val_acc: 0.9721
# Epoch 3/40
# 60000/60000 [==============================] - 8s 139us/step - loss: 0.0712 - acc: 0.9782 - val_loss: 0.0779 - val_acc: 0.9768
# Epoch 4/40
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0561 - acc: 0.9833 - val_loss: 0.0843 - val_acc: 0.9771
# Epoch 5/40
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.0454 - acc: 0.9863 - val_loss: 0.0955 - val_acc: 0.9766
# Epoch 6/40
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.0399 - acc: 0.9880 - val_loss: 0.0903 - val_acc: 0.9757
# Epoch 7/40
# 60000/60000 [==============================] - 8s 131us/step - loss: 0.0386 - acc: 0.9888 - val_loss: 0.0780 - val_acc: 0.9810
# Epoch 8/40
# 60000/60000 [==============================] - 8s 134us/step - loss: 0.0311 - acc: 0.9911 - val_loss: 0.0900 - val_acc: 0.9824
# Epoch 9/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0292 - acc: 0.9917 - val_loss: 0.0966 - val_acc: 0.9803
# Epoch 10/40
# 60000/60000 [==============================] - 8s 141us/step - loss: 0.0275 - acc: 0.9926 - val_loss: 0.1062 - val_acc: 0.9810
# Epoch 11/40
# 60000/60000 [==============================] - 8s 134us/step - loss: 0.0248 - acc: 0.9932 - val_loss: 0.1069 - val_acc: 0.9816
# Epoch 12/40
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.0242 - acc: 0.9935 - val_loss: 0.1175 - val_acc: 0.9792
# Epoch 13/40
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0217 - acc: 0.9943 - val_loss: 0.1155 - val_acc: 0.9839
# Epoch 14/40
# 60000/60000 [==============================] - 9s 142us/step - loss: 0.0224 - acc: 0.9941 - val_loss: 0.1030 - val_acc: 0.9845
# Epoch 15/40
# 60000/60000 [==============================] - 8s 131us/step - loss: 0.0215 - acc: 0.9945 - val_loss: 0.1114 - val_acc: 0.9831
# Epoch 16/40
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.0216 - acc: 0.9946 - val_loss: 0.1126 - val_acc: 0.9836
# Epoch 17/40
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.0215 - acc: 0.9947 - val_loss: 0.1299 - val_acc: 0.9806
# Epoch 18/40
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.0189 - acc: 0.9952 - val_loss: 0.1102 - val_acc: 0.9840
# Epoch 19/40
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0184 - acc: 0.9954 - val_loss: 0.1222 - val_acc: 0.9816
# Epoch 20/40
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0174 - acc: 0.9956 - val_loss: 0.1212 - val_acc: 0.9830
# Epoch 21/40
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0191 - acc: 0.9954 - val_loss: 0.1200 - val_acc: 0.9825
# Epoch 22/40
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0180 - acc: 0.9959 - val_loss: 0.1282 - val_acc: 0.9829
# Epoch 23/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0173 - acc: 0.9960 - val_loss: 0.1338 - val_acc: 0.9829
# Epoch 24/40
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0163 - acc: 0.9964 - val_loss: 0.1326 - val_acc: 0.9832
# Epoch 25/40
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0158 - acc: 0.9964 - val_loss: 0.1233 - val_acc: 0.9846
# Epoch 26/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0153 - acc: 0.9964 - val_loss: 0.1147 - val_acc: 0.9861
# Epoch 27/40
# 60000/60000 [==============================] - 9s 152us/step - loss: 0.0164 - acc: 0.9968 - val_loss: 0.1279 - val_acc: 0.9846
# Epoch 28/40
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0159 - acc: 0.9964 - val_loss: 0.1293 - val_acc: 0.9831
# Epoch 29/40
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0153 - acc: 0.9965 - val_loss: 0.1346 - val_acc: 0.9840
# Epoch 30/40
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0151 - acc: 0.9968 - val_loss: 0.1198 - val_acc: 0.9858
# Epoch 31/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0167 - acc: 0.9964 - val_loss: 0.1285 - val_acc: 0.9851
# Epoch 32/40
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.0133 - acc: 0.9969 - val_loss: 0.1305 - val_acc: 0.9844
# Epoch 33/40
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0146 - acc: 0.9970 - val_loss: 0.1197 - val_acc: 0.9853
# Epoch 34/40
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0135 - acc: 0.9971 - val_loss: 0.1407 - val_acc: 0.9835
# Epoch 35/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0133 - acc: 0.9970 - val_loss: 0.1445 - val_acc: 0.9839
# Epoch 36/40
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0153 - acc: 0.9972 - val_loss: 0.1348 - val_acc: 0.9846
# Epoch 37/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0165 - acc: 0.9969 - val_loss: 0.1278 - val_acc: 0.9842
# Epoch 38/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0110 - acc: 0.9976 - val_loss: 0.1243 - val_acc: 0.9851
# Epoch 39/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0124 - acc: 0.9976 - val_loss: 0.1222 - val_acc: 0.9860
# Epoch 40/40
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0137 - acc: 0.9974 - val_loss: 0.1457 - val_acc: 0.9836
# Test loss: 0.14565400976759052
# Test accuracy: 0.9836

# %% [markdown]
# ## Three Hidden Layers

# %%
three_hidden_model = Sequential()
three_hidden_model.add(Dense(800, activation='relu', input_shape=(784,)))
three_hidden_model.add(Dropout(0.2))
three_hidden_model.add(Dense(400, activation='relu'))
three_hidden_model.add(Dropout(0.2))
three_hidden_model.add(Dense(200, activation='relu'))
three_hidden_model.add(Dropout(0.2))
three_hidden_model.add(Dense(num_classes, activation='softmax'))

three_hidden_history = test_model(three_hidden_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 800)               628000
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 800)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 400)               320400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 200)               80200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                2010
# =================================================================
# Total params: 1,030,610
# Trainable params: 1,030,610
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 10s 171us/step - loss: 0.2707 - acc: 0.9159 - val_loss: 0.1226 - val_acc: 0.9642
# Epoch 2/40
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.1117 - acc: 0.9676 - val_loss: 0.0856 - val_acc: 0.9736
# Epoch 3/40
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0832 - acc: 0.9759 - val_loss: 0.0862 - val_acc: 0.9763
# Epoch 4/40
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0682 - acc: 0.9803 - val_loss: 0.1066 - val_acc: 0.9732
# Epoch 5/40
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0613 - acc: 0.9828 - val_loss: 0.0850 - val_acc: 0.9803
# Epoch 6/40
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0546 - acc: 0.9852 - val_loss: 0.0987 - val_acc: 0.9783
# Epoch 7/40
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0523 - acc: 0.9866 - val_loss: 0.0834 - val_acc: 0.9823
# Epoch 8/40
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0495 - acc: 0.9874 - val_loss: 0.0803 - val_acc: 0.9837
# Epoch 9/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0502 - acc: 0.9879 - val_loss: 0.1069 - val_acc: 0.9773
# Epoch 10/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0478 - acc: 0.9881 - val_loss: 0.0840 - val_acc: 0.9826
# Epoch 11/40
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0415 - acc: 0.9899 - val_loss: 0.0914 - val_acc: 0.9823
# Epoch 12/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0421 - acc: 0.9906 - val_loss: 0.0887 - val_acc: 0.9837
# Epoch 13/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0409 - acc: 0.9909 - val_loss: 0.1051 - val_acc: 0.9817
# Epoch 14/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0431 - acc: 0.9904 - val_loss: 0.0910 - val_acc: 0.9826
# Epoch 15/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0417 - acc: 0.9914 - val_loss: 0.1294 - val_acc: 0.9808
# Epoch 16/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0407 - acc: 0.9915 - val_loss: 0.1155 - val_acc: 0.9831
# Epoch 17/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0385 - acc: 0.9921 - val_loss: 0.1312 - val_acc: 0.9819
# Epoch 18/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0381 - acc: 0.9924 - val_loss: 0.1036 - val_acc: 0.9860
# Epoch 19/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0401 - acc: 0.9922 - val_loss: 0.1244 - val_acc: 0.9843
# Epoch 20/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0431 - acc: 0.9918 - val_loss: 0.1300 - val_acc: 0.9828
# Epoch 21/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0341 - acc: 0.9933 - val_loss: 0.1510 - val_acc: 0.9814
# Epoch 22/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0419 - acc: 0.9925 - val_loss: 0.1344 - val_acc: 0.9828
# Epoch 23/40
# 60000/60000 [==============================] - 10s 166us/step - loss: 0.0391 - acc: 0.9929 - val_loss: 0.1238 - val_acc: 0.9851
# Epoch 24/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0400 - acc: 0.9929 - val_loss: 0.1287 - val_acc: 0.9819
# Epoch 25/40
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0373 - acc: 0.9930 - val_loss: 0.1242 - val_acc: 0.9855
# Epoch 26/40
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0390 - acc: 0.9933 - val_loss: 0.1322 - val_acc: 0.9825
# Epoch 27/40
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0407 - acc: 0.9932 - val_loss: 0.1485 - val_acc: 0.9829
# Epoch 28/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0398 - acc: 0.9932 - val_loss: 0.1162 - val_acc: 0.9848
# Epoch 29/40
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0377 - acc: 0.9935 - val_loss: 0.1417 - val_acc: 0.9837
# Epoch 30/40
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0451 - acc: 0.9933 - val_loss: 0.1286 - val_acc: 0.9848
# Epoch 31/40
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0420 - acc: 0.9935 - val_loss: 0.1458 - val_acc: 0.9836
# Epoch 32/40
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0432 - acc: 0.9935 - val_loss: 0.1405 - val_acc: 0.9846
# Epoch 33/40
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0393 - acc: 0.9943 - val_loss: 0.1405 - val_acc: 0.9828
# Epoch 34/40
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.0397 - acc: 0.9939 - val_loss: 0.1649 - val_acc: 0.9829
# Epoch 35/40
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0405 - acc: 0.9940 - val_loss: 0.1479 - val_acc: 0.9827
# Epoch 36/40
# 60000/60000 [==============================] - 10s 166us/step - loss: 0.0369 - acc: 0.9941 - val_loss: 0.1301 - val_acc: 0.9851
# Epoch 37/40
# 60000/60000 [==============================] - 10s 167us/step - loss: 0.0390 - acc: 0.9940 - val_loss: 0.1531 - val_acc: 0.9828
# Epoch 38/40
# 60000/60000 [==============================] - 10s 168us/step - loss: 0.0378 - acc: 0.9946 - val_loss: 0.1711 - val_acc: 0.9827
# Epoch 39/40
# 60000/60000 [==============================] - 10s 167us/step - loss: 0.0381 - acc: 0.9946 - val_loss: 0.1473 - val_acc: 0.9849
# Epoch 40/40
# 60000/60000 [==============================] - 10s 166us/step - loss: 0.0377 - acc: 0.9947 - val_loss: 0.1621 - val_acc: 0.9837
# Test loss: 0.16211408954398857
# Test accuracy: 0.9837

# %% [markdown]
# ## Plotting

# %%
plt.figure(1)
plt.title("Train Accuracy Vs. Epoch")
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')
# summarize history for accuracy  
plt.plot(no_hidden_history.history['acc']) 
plt.plot(one_hidden_history.history['acc']) 
plt.plot(two_hidden_history.history['acc'])
plt.plot(three_hidden_history.history['acc'])
plt.legend(['No Hidden Layer', 'One Hidden Layer', 'Two Hidden Layers', 'Three Hidden Layers'], loc='lower right') 

plt.figure(2)
plt.title("Validation Accuracy Vs. Epoch")
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')
# summarize history for accuracy  
plt.plot(no_hidden_history.history['val_acc']) 
plt.plot(one_hidden_history.history['val_acc']) 
plt.plot(two_hidden_history.history['val_acc'])
plt.plot(three_hidden_history.history['val_acc'])
plt.legend(['No Hidden Layer', 'One Hidden Layer', 'Two Hidden Layers', 'Three Hidden Layers'], loc='lower right')
